# %%
# !pip uninstall tensorflow tensorflow-tensorboard tensorflow-estimator
# !pip install gdown
# !pip install tensorflow-gpu

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.preprocessing import MinMaxScaler
from pandas.plotting import register_matplotlib_converters
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

register_matplotlib_converters()
sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 22, 10

RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

scaler = MinMaxScaler(feature_range=(0, 1))

# %%
df = pd.read_csv(
  "/home/jovyan/work/training_data/sw_training_data.csv", 
  parse_dates=['read_date'], 
  index_col="read_date"
)

# %%
df = df.drop(['bl_meter1','bl_meter2','bl_meter3','bl_ahd3','mean_temp3','bl_meter4','bl_ahd4','mean_temp4','sl_meter','rf_meter'
             ],axis=1)

# %%
df.shape
# Out:
# (5297, 6)

# %%
df.head()
# Out:
#             sl_read1  bl_ahd1  mean_temp1  bl_ahd2  mean_temp2  rf_read1
# read_date
# 2005-12-02     0.295  253.271      19.800  251.641      21.400      19.8
# 2005-12-03     0.303  253.277      19.825  251.644      21.350      21.4
# 2005-12-04     0.307  253.278      19.800  251.639      21.375       0.0
# 2005-12-05     0.303  253.275      19.824  251.636      21.375       0.0
# 2005-12-06     0.304  253.273      19.801  251.638      21.400       0.0

# %%
sns.lineplot(x=df.index, y="sl_read1", data=df);

# %%
# read_date sl_read1 	bl_ahd1 	mean_temp1 	bl_ahd2 	mean_temp2 	rf_read1
def create_data():
    
    df1 = df.copy()
    df2 = df.copy()
    df2 = df2.drop(['mean_temp1','mean_temp2','rf_read1'],axis=1)
    
    #df1, df2 = scale_input(df1,df2) 

    return(df1,df2)

# %%
def create_train(X,Y):
    train_size = int(len(X) * 0.75)
    X_train, Y_train = X[0:train_size], Y[0:train_size]
#    print(X_train, Y_train)
    return X_train, Y_train

# %%
def create_test(X,Y):
    train_size = int(len(X) * 0.75)
    X_test, Y_test = X[train_size:(len(X))], Y[train_size:(len(X))]
#    print(X_test, Y_test)
    return X_test, Y_test

# %%
def create_dataset(datax, datay, step):
    X, Y = [], []
    for i in range(len(datax) - step):
        d = i + step  
        X.append(datax[i:d,])
        Y.append(datay[d])
        
    return np.array(X), np.array(Y)

# %%
def normalise_dataset(X,Y):

    X, Y = scaler.fit_transform(X), scaler.fit_transform(Y)
    
    return np.array(X), np.array(Y)

# %%
#def create_lineplot(X_train, X_test):
#    
#    print (X_train)
#    sns.lineplot(x=X_train.index, y=X_train[0], data=X_train);
#    sns.lineplot(x=X_test.index, y=X_test[0], data=X_test);
#    
#    #sns.lineplot(x=X_train.index, y="sl_read1", data=X_train);
#    #sns.lineplot(x=X_test.index, y="sl_read1", data=X_test);
#    #sns.distplot(np.log1p(df.price))

# %%
time_steps = 10

Xs,Ys = create_data()

Xs_train, Ys_train = create_train(Xs,Ys) 
Xs_test, Ys_test = create_test(Xs,Ys)

Xs_train, Ys_train = normalise_dataset(Xs_train,Ys_train)
Xs_test, Ys_test = normalise_dataset(Xs_test,Ys_test)

X_train, Y_train = create_dataset(Xs_train,Ys_train, time_steps)
X_test, Y_test = create_dataset(Xs_test,Ys_test, time_steps)

print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (3962, 10, 6) (3962, 3)
# (1315, 10, 6) (1315, 3)

# %%
model = keras.Sequential()
model.add(
  keras.layers.Bidirectional(
    keras.layers.LSTM(
      units=128, 
      input_shape=(X_train.shape[1], X_train.shape[2])
    )
  )
)
model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.Dense(units=3))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
history = model.fit(
    X_train, Y_train, 
    epochs=30, 
    batch_size=32, 
    validation_split=0.1,
    shuffle=False
)
# Out:
# Epoch 1/30
# 112/112 [==============================] - 5s 19ms/step - loss: 0.0213 - val_loss: 0.0053
# Epoch 2/30
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 3/30
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0043 - val_loss: 0.0037
# Epoch 4/30
# 112/112 [==============================] - 1s 13ms/step - loss: 0.0042 - val_loss: 0.0031
# Epoch 5/30
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0039 - val_loss: 0.0026
# Epoch 6/30
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0035 - val_loss: 0.0020
# Epoch 7/30
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 8/30
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 9/30
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0015 - val_loss: 7.7665e-04
# Epoch 10/30
# 112/112 [==============================] - 2s 15ms/step - loss: 9.9336e-04 - val_loss: 6.8289e-04
# Epoch 11/30
# 112/112 [==============================] - 2s 14ms/step - loss: 7.7294e-04 - val_loss: 6.0164e-04
# Epoch 12/30
# 112/112 [==============================] - 2s 16ms/step - loss: 6.2794e-04 - val_loss: 6.5389e-04
# Epoch 13/30
# 112/112 [==============================] - 2s 15ms/step - loss: 6.4257e-04 - val_loss: 7.3916e-04
# Epoch 14/30
# 112/112 [==============================] - 2s 15ms/step - loss: 5.6848e-04 - val_loss: 7.0025e-04
# Epoch 15/30
# 112/112 [==============================] - 2s 15ms/step - loss: 5.7933e-04 - val_loss: 7.0688e-04
# Epoch 16/30
# 112/112 [==============================] - 2s 13ms/step - loss: 5.7813e-04 - val_loss: 6.6008e-04
# Epoch 17/30
# 112/112 [==============================] - 2s 15ms/step - loss: 5.4631e-04 - val_loss: 6.6618e-04
# Epoch 18/30
# 112/112 [==============================] - 2s 14ms/step - loss: 5.7600e-04 - val_loss: 6.1773e-04
# Epoch 19/30
# 112/112 [==============================] - 2s 15ms/step - loss: 5.8417e-04 - val_loss: 6.1262e-04
# Epoch 20/30
# 112/112 [==============================] - 2s 15ms/step - loss: 5.5910e-04 - val_loss: 5.8721e-04
# Epoch 21/30
# 112/112 [==============================] - 2s 14ms/step - loss: 5.8905e-04 - val_loss: 5.8311e-04
# Epoch 22/30
# 112/112 [==============================] - 1s 13ms/step - loss: 5.4902e-04 - val_loss: 6.2179e-04
# Epoch 23/30
# 112/112 [==============================] - 2s 16ms/step - loss: 5.9290e-04 - val_loss: 5.8544e-04
# Epoch 24/30
# 112/112 [==============================] - 2s 14ms/step - loss: 5.3764e-04 - val_loss: 5.9340e-04
# Epoch 25/30
# 112/112 [==============================] - 2s 15ms/step - loss: 5.1678e-04 - val_loss: 6.2149e-04
# Epoch 26/30
# 112/112 [==============================] - 2s 14ms/step - loss: 5.3540e-04 - val_loss: 5.7876e-04
# Epoch 27/30
# 112/112 [==============================] - 2s 14ms/step - loss: 5.5506e-04 - val_loss: 6.2341e-04
# Epoch 28/30
# 112/112 [==============================] - 2s 15ms/step - loss: 5.4903e-04 - val_loss: 5.5892e-04
# Epoch 29/30
# 112/112 [==============================] - 1s 13ms/step - loss: 5.2743e-04 - val_loss: 6.3462e-04
# Epoch 30/30
# 112/112 [==============================] - 2s 17ms/step - loss: 5.1792e-04 - val_loss: 5.7664e-04

# %%
model2 = keras.Sequential()
model2.add(
  keras.layers.Bidirectional(
    keras.layers.LSTM(
      units=128, 
      input_shape=(X_train.shape[1], X_train.shape[2])
    )
  )
)
model2.add(keras.layers.Dropout(rate=0.2)),
model2.add(keras.layers.Dense(units=32, activation='relu')),
model2.add(keras.layers.Dropout(rate=0.2)),
model2.add(keras.layers.Dense(units=16, activation='relu')),
model2.add(keras.layers.Dense(units=3, activation='linear')),
model2.compile(loss='mean_squared_error', optimizer='adam')

# %%
history2 = model2.fit(
    X_train, Y_train, 
    epochs=30, 
    batch_size=32, 
    validation_split=0.1,
    shuffle=False
)
# Out:
# Epoch 1/30
# 112/112 [==============================] - 5s 20ms/step - loss: 37348.4966 - val_loss: 2980.6284
# Epoch 2/30
# 112/112 [==============================] - 2s 14ms/step - loss: 1279.4573 - val_loss: 19.5020
# Epoch 3/30
# 112/112 [==============================] - 2s 15ms/step - loss: 659.3119 - val_loss: 36.9047
# Epoch 4/30
# 112/112 [==============================] - 2s 15ms/step - loss: 650.6817 - val_loss: 42.9247
# Epoch 5/30
# 112/112 [==============================] - 2s 14ms/step - loss: 571.4538 - val_loss: 37.5023
# Epoch 6/30
# 112/112 [==============================] - 2s 15ms/step - loss: 596.9417 - val_loss: 24.3499
# Epoch 7/30
# 112/112 [==============================] - 2s 16ms/step - loss: 595.1518 - val_loss: 37.5910
# Epoch 8/30
# 112/112 [==============================] - 2s 16ms/step - loss: 600.0072 - val_loss: 51.9872
# Epoch 9/30
# 112/112 [==============================] - 2s 15ms/step - loss: 599.5405 - val_loss: 27.0852
# Epoch 10/30
# 112/112 [==============================] - 2s 14ms/step - loss: 583.4881 - val_loss: 87.1618
# Epoch 11/30
# 112/112 [==============================] - 2s 16ms/step - loss: 565.9444 - val_loss: 14.8160
# Epoch 12/30
# 112/112 [==============================] - 2s 14ms/step - loss: 569.2092 - val_loss: 43.8263
# Epoch 13/30
# 112/112 [==============================] - 2s 16ms/step - loss: 602.6673 - val_loss: 63.2582
# Epoch 14/30
# 112/112 [==============================] - 2s 17ms/step - loss: 549.4223 - val_loss: 63.2111
# Epoch 15/30
# 112/112 [==============================] - 2s 16ms/step - loss: 581.1397 - val_loss: 125.5186
# Epoch 16/30
# 112/112 [==============================] - 2s 15ms/step - loss: 547.5989 - val_loss: 127.6469
# Epoch 17/30
# 112/112 [==============================] - 2s 14ms/step - loss: 549.3175 - val_loss: 131.7505
# Epoch 18/30
# 112/112 [==============================] - 2s 16ms/step - loss: 564.1511 - val_loss: 125.5455
# Epoch 19/30
# 112/112 [==============================] - 2s 16ms/step - loss: 539.9376 - val_loss: 151.9523
# Epoch 20/30
# 112/112 [==============================] - 2s 14ms/step - loss: 521.4767 - val_loss: 135.5050
# Epoch 21/30
# 112/112 [==============================] - 2s 16ms/step - loss: 507.4379 - val_loss: 174.6305
# Epoch 22/30
# 112/112 [==============================] - 2s 15ms/step - loss: 509.5498 - val_loss: 214.8244
# Epoch 23/30
# 112/112 [==============================] - 2s 14ms/step - loss: 506.8419 - val_loss: 253.8093
# Epoch 24/30
# 112/112 [==============================] - 2s 16ms/step - loss: 469.0882 - val_loss: 244.7569
# Epoch 25/30
# 112/112 [==============================] - 2s 16ms/step - loss: 466.1490 - val_loss: 258.0682
# Epoch 26/30
# 112/112 [==============================] - 2s 14ms/step - loss: 422.4101 - val_loss: 189.5220
# Epoch 27/30
# 112/112 [==============================] - 2s 14ms/step - loss: 420.7592 - val_loss: 343.2743
# Epoch 28/30
# 112/112 [==============================] - 2s 16ms/step - loss: 400.0768 - val_loss: 430.8337
# Epoch 29/30
# 112/112 [==============================] - 2s 15ms/step - loss: 359.7510 - val_loss: 542.6097
# Epoch 30/30
# 112/112 [==============================] - 2s 16ms/step - loss: 309.0535 - val_loss: 682.1348

# %%
plt.plot(history2.history['loss'], label='train')
plt.plot(history2.history['val_loss'], label='test')
plt.legend();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-2bac6bba460f> in <module>
# ----> 1 plt.plot(history2.history['loss'], label='train')
#       2 plt.plot(history2.history['val_loss'], label='test')
#       3 plt.legend();
#
# NameError: name 'history2' is not defined

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend();

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
Y_pred = model.predict(X_test)

# %%
print(Y_pred)
print(Y_pred.shape)
# Out:
# [[0.12453648 0.77932596 0.9512076 ]
#  [0.12506208 0.78005815 0.9502954 ]
#  [0.12465957 0.7783544  0.9475488 ]
#  ...
#  [0.16062808 0.76876724 0.7118519 ]
#  [0.1616902  0.7737216  0.71699494]
#  [0.16077346 0.7720275  0.7162623 ]]
# (1315, 3)

# %%
Y_train_inv = scaler.inverse_transform(Y_train)
Y_test_inv = scaler.inverse_transform(Y_test)
Y_pred_inv = scaler.inverse_transform(Y_pred)

# %%
print(Y_pred_inv)
print(Y_pred_inv.shape)
print(Y_train_inv)
print(Y_train_inv.shape)
print(scaler.inverse_transform(X_train))
# Out:
# [[2.4239187e-01 2.5263574e+02 2.5162195e+02]
#  [2.4308145e-01 2.5263721e+02 2.5162036e+02]
#  [2.4255335e-01 2.5263382e+02 2.5161557e+02]
#  ...
#  [2.8974405e-01 2.5261469e+02 2.5120477e+02]
#  [2.9113755e-01 2.5262457e+02 2.5121373e+02]
#  [2.8993478e-01 2.5262120e+02 2.5121245e+02]]
# (1315, 3)
# [[1.52887367e-01 2.51784030e+02 2.50810045e+02]
#  [1.53286758e-01 2.51788256e+02 2.50812822e+02]
#  [1.52088584e-01 2.51780333e+02 2.50802639e+02]
#  ...
#  [1.10152511e-01 2.51658847e+02 2.50847996e+02]
#  [1.11350685e-01 2.51668883e+02 2.50873914e+02]
#  [1.11350685e-01 2.51666770e+02 2.50873914e+02]]
# (3962, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-12f868e5f9fb> in <module>
#       3 print(Y_train_inv)
#       4 print(Y_train_inv.shape)
# ----> 5 print(scaler.inverse_transform(X_train))
#
# /opt/conda/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X)
#     427         check_is_fitted(self)
#     428
# --> 429         X = check_array(X, copy=self.copy, dtype=FLOAT_DTYPES,
#     430                         force_all_finite="allow-nan")
#     431
#
# /opt/conda/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/conda/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     638             array = array.astype(np.float64)
#     639         if not allow_nd and array.ndim >= 3:
# --> 640             raise ValueError("Found array with dim %d. %s expected <= 2."
#     641                              % (array.ndim, estimator_name))
#     642
#
# ValueError: Found array with dim 3. Estimator expected <= 2.

# %%
plt.plot(np.arange(0, len(Y_train)), Y_train_inv[:,0].flatten(), 'g', label="history")
plt.plot(np.arange(len(Y_train), len(Y_train) + len(Y_test)), Y_test_inv[:,0].flatten(), marker='.', label="true")
plt.plot(np.arange(len(Y_train), len(Y_train) + len(Y_test)), Y_pred_inv[:,0].flatten(), 'r', label="prediction")
plt.ylabel('CF419051')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
plt.plot(np.arange(0, len(Y_train)), Y_train_inv[:,1].flatten(), 'g', label="history")
plt.plot(np.arange(len(Y_train), len(Y_train) + len(Y_test)), Y_test_inv[:,1].flatten(), marker='.', label="true")
plt.plot(np.arange(len(Y_train), len(Y_train) + len(Y_test)), Y_pred_inv[:,1].flatten(), 'r', label="prediction")
plt.plot(np.arange(0, len(Y_train)), Y_train_inv[:,2].flatten(), 'g', label="history")
plt.plot(np.arange(len(Y_train), len(Y_train) + len(Y_test)), Y_test_inv[:,2].flatten(), marker='.', label="true")
plt.plot(np.arange(len(Y_train), len(Y_train) + len(Y_test)), Y_pred_inv[:,2].flatten(), 'r', label="prediction")
plt.ylabel('CF419051')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
Y_pred2 = model2.predict(X_test)

# %%
plt.plot(np.arange(0, len(Y_train)), Y_train_inv[:,0].flatten(), 'g', label="history")
plt.plot(np.arange(len(Y_train), len(Y_train) + len(Y_test)), Y_test[:,0].flatten(), marker='.', label="true")
plt.plot(np.arange(len(Y_train), len(Y_train) + len(Y_test)), Y_pred2[:,0].flatten(), 'r', label="prediction")
plt.ylabel('CF419051')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
plt.plot(np.arange(0, len(Y_train)), Y_train_inv[:,1].flatten(), 'g', label="history")
plt.plot(np.arange(len(Y_train), len(Y_train) + len(Y_test)), Y_test[:,1].flatten(), marker='.', label="true")
plt.plot(np.arange(len(Y_train), len(Y_train) + len(Y_test)), Y_pred2[:,1].flatten(), 'r', label="prediction")
plt.ylabel('CF419051')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
plt.plot(np.arange(0, len(Y_train)), Y_train_inv[:,2].flatten(), 'g', label="history")
plt.plot(np.arange(len(Y_train), len(Y_train) + len(Y_test)), Y_test[:,2].flatten(), marker='.', label="true")
plt.plot(np.arange(len(Y_train), len(Y_train) + len(Y_test)), Y_pred2[:,2].flatten(), 'r', label="prediction")
plt.ylabel('CF419051')
plt.xlabel('Time Step')
plt.legend()
plt.show();
