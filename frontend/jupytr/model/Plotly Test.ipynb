# %%
# !pip install plotly.express
# Out:
# ...
#      |████████████████████████████████| 23.9 MB 13 kB/s  eta 0:00:01     |██████████████████████▋         | 16.9 MB 685 kB/s eta 0:00:11     |█████████████████████████▊      | 19.2 MB 1.6 MB/s eta 0:00:03
# ...

# %%
import pandas as pd
import plotly.express as px
import seaborn as sns


def show_cor(df):    
    
#    df2 = df1.drop(columns=['Rainfall_MA90'])

    fig = px.imshow(df,title='Correlation Heatmap')
    return fig




df1 = pd.DataFrame({'GW967137.1.1':[1.000000,0.868643,0.741188,0.018659,0.301556],
                    'GW967137.2.2':[0.868643,1.000000,0.506081,0.014930,0.121363],
                    'Elfin Crossing':[0.741188,0.506081,1.000000,0.063414,0.505518],
                    'Kaputar Rainfall':[0.018659,0.014930,0.063414,1.000000,0.120831],
                    'Rainfall MA90':[0.301556,0.121363,0.505518,0.120831,1.000000]},
                    columns=['GW967137.1.1','GW967137.2.2','Elfin Crossing','Kaputar Rainfall','Rainfall MA90'])

df2 = pd.DataFrame({'GW967137.1.1':[1.000000,0.868643,0.741188,0.018659],
                    'GW967137.2.2':[0.868643,1.000000,0.506081,0.014930],
                    'Elfin Crossing':[0.741188,0.506081,1.000000,0.063414],
                    'Kaputar Rainfall':[0.018659,0.014930,0.063414,1.000000]},
                    columns=['GW967137.1.1','GW967137.2.2','Elfin Crossing','Kaputar Rainfall'])

sns.heatmap(df1,annot=True)
#fig1 = px.imshow(df1,title='Correlation Heatmap')
##fig1 = show_cor(df1)
#fig1.show()
# Out:
# <AxesSubplot:>
