# %%
# !pip uninstall tensorflow tensorflow-tensorboard tensorflow-estimator
# !pip install gdown
# !pip install tensorflow-gpu
# Out:
# Requirement already satisfied: gdown in /opt/conda/lib/python3.8/site-packages (3.12.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.8/site-packages (from gdown) (4.54.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from gdown) (1.15.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.8/site-packages (from gdown) (3.0.12)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.8/site-packages (from gdown) (2.25.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (2020.11.8)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (1.25.11)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (2020.11.8)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (1.25.11)
# Requirement already satisfied: tensorflow-gpu in /opt/conda/lib/python3.8/site-packages (2.4.1)
# Requirement already satisfied: wheel~=0.35 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (0.36.0)
# Requirement already satisfied: h5py~=2.10.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: google-pasta~=0.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: absl-py~=0.10 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (0.11.0)
# Requirement already satisfied: termcolor~=1.1.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.12)
# Requirement already satisfied: numpy~=1.19.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.19.4)
# Requirement already satisfied: wrapt~=1.12.1 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.12.1)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (2.4.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: gast==0.3.3 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (0.3.3)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: tensorboard~=2.4 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (2.4.1)
# Requirement already satisfied: astunparse~=1.6.3 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (3.13.0)
# Requirement already satisfied: grpcio~=1.32.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.32.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (3.7.4.3)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: wheel~=0.35 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (0.36.0)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: numpy~=1.19.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.19.4)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: numpy~=1.19.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.19.4)
# Requirement already satisfied: numpy~=1.19.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.19.4)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from protobuf>=3.9.2->tensorflow-gpu) (49.6.0.post20201009)
# Requirement already satisfied: wheel~=0.35 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (0.36.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from protobuf>=3.9.2->tensorflow-gpu) (49.6.0.post20201009)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow-gpu) (0.4.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow-gpu) (3.3.4)
# Requirement already satisfied: numpy~=1.19.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.19.4)
# Requirement already satisfied: absl-py~=0.10 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (0.11.0)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (3.13.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/conda/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow-gpu) (1.27.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow-gpu) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow-gpu) (2.25.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/conda/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow-gpu) (1.8.0)
# Requirement already satisfied: grpcio~=1.32.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.32.0)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu) (4.2.1)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from protobuf>=3.9.2->tensorflow-gpu) (49.6.0.post20201009)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/conda/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow-gpu) (1.27.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow-gpu) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu) (2020.11.8)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow-gpu) (3.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow-gpu) (2.25.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu) (0.4.8)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import train_test_split
from pandas.plotting import register_matplotlib_converters

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

register_matplotlib_converters()
sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 22, 10

RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
df = pd.read_csv(
  "/home/jovyan/work/training_data/sw_training_data.csv", 
  parse_dates=['read_date'], 
  index_col="read_date"
)

# %%
df = df.drop(['bl_meter1','bl_meter2','bl_meter3','bl_ahd3','mean_temp3','bl_meter4','bl_ahd4','mean_temp4','sl_meter','rf_meter'
             ],axis=1)

# %%
df.shape
# Out:
# (5297, 6)

# %%
df.shape[0]
# Out:
# 5297

# %%
df.shape[1]
# Out:
# 6

# %%
df.head()
# Out:
#             sl_read1  bl_ahd1  mean_temp1  bl_ahd2  mean_temp2  rf_read1
# read_date
# 2005-12-02     0.295  253.271      19.800  251.641      21.400      19.8
# 2005-12-03     0.303  253.277      19.825  251.644      21.350      21.4
# 2005-12-04     0.307  253.278      19.800  251.639      21.375       0.0
# 2005-12-05     0.303  253.275      19.824  251.636      21.375       0.0
# 2005-12-06     0.304  253.273      19.801  251.638      21.400       0.0

# %%
sns.lineplot(x=df.index, y="sl_read1", data=df);

# %%
train_size = int(len(df) * 0.75)
test_size = len(df) - train_size
train, test = df.iloc[0:train_size], df.iloc[train_size:len(df)]
#df_test=test.copy()
print(len(train), len(test))
# Out:
# 3972 1325

# %%
sns.lineplot(x=train.index, y="sl_read1", data=train);
sns.lineplot(x=test.index, y="sl_read1", data=test);

# %% [markdown]
# # Skip

# %%
from sklearn.preprocessing import RobustScaler


rf_columns = ['mean_temp1','mean_temp2','rf_read1']
sl_columns = ['bl_ahd1', 'bl_ahd2','sl_read1']

rf_transformer = RobustScaler()
sl_transformer = RobustScaler()

rf_transformer = rf_transformer.fit(train[rf_columns].to_numpy())
sl_transformer = sl_transformer.fit(train[sl_columns].to_numpy())

train.loc[:, rf_columns] = rf_transformer.transform(train[rf_columns].to_numpy())
train.loc[:, sl_columns] = sl_transformer.transform(train[sl_columns].to_numpy())

test.loc[:, rf_columns] = rf_transformer.transform(test[rf_columns].to_numpy())
test.loc[:, sl_columns] = sl_transformer.transform(test[sl_columns].to_numpy())



# f_transformer = f_transformer.fit(train[f_columns].to_numpy())
# sl_transformer = sl_transformer.fit(train[y_columns].to_numpy())
# 
# 
# 
# train.loc[:, f_columns] = f_transformer.transform(train[f_columns].to_numpy())
# train.loc[:, y_columns] = sl_transformer.transform(train[y_columns].to_numpy())
# 
# test.loc[:, f_columns] = f_transformer.transform(test[f_columns].to_numpy())
# test.loc[:, y_columns] = sl_transformer.transform(train[y_columns].to_numpy())
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-13-8be39b4a597e>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[:, rf_columns] = rf_transformer.transform(train[rf_columns].to_numpy())
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-13-8be39b4a597e>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[:, sl_columns] = sl_transformer.transform(train[sl_columns].to_numpy())
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-13-8be39b4a597e>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.loc[:, rf_columns] = rf_transformer.transform(test[rf_columns].to_numpy())
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-13-8be39b4a597e>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.loc[:, sl_columns] = sl_transformer.transform(test[sl_columns].to_numpy())

# %% [markdown]
# # Skip

# %%
def create_dataset(X, y1, y2, y3, time_steps=1):
    
    Xs, y1s, y2s, y3s = [], [], [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)
        y1s.append(y1.iloc[i + time_steps])
        y2s.append(y2.iloc[i + time_steps])
        y3s.append(y3.iloc[i + time_steps])
        
    
    return np.array(Xs), np.array(y1s), np.array(y2s), np.array(y3s)

# %%
#def create_dataset(datax, datay, step):
#    X, Y = [], []
#    for i in range(len(datax)-step):
#          d = i+step  
#          X.append(datax[i:d,])
#          Y.append(datay[d])
#     
#    return array(X), array(Y)

# %%
time_steps = 10

train_sl = ['train.bl_ahd1', 'train.bl_ahd2','train.sl_read1']
test_sl = ['test.bl_ahd1', 'test.bl_ahd2','test.sl_read1']
# reshape to [samples, time_steps, n_features]

# X_train, Y_train = create_dataset(train, train.sl_read1, time_steps)
# X_test, Y_test = create_dataset(test,test.sl_read1, time_steps)

X_train, y1_train, y2_train, y3_train = create_dataset(train, train.bl_ahd1,train.bl_ahd2,train.sl_read1,time_steps)
X_test, y1_test, y2_test, y3_test = create_dataset(test,test.bl_ahd1,test.bl_ahd2,test.sl_read1, time_steps)

Y_train = np.concatenate((y1_train, y3_train, y3_train))
print(X_train.shape, Y_train.shape, y1_train.shape, y2_train.shape, y3_train.shape)
# print(X_train)
# print(Y_train)
# Out:
# (3962, 10, 6) (11886,) (3962,) (3962,) (3962,)
# [[[ 3.92307692e+00  8.33648393e-01 -1.66320166e-03  4.32330827e-02
#     1.57842815e+00  9.90000000e+01]
#   [ 4.23076923e+00  8.56332703e-01  3.99168399e-02  4.88721805e-02
#     1.51266031e+00  1.07000000e+02]
#   [ 4.38461538e+00  8.60113422e-01 -1.66320166e-03  3.94736842e-02
#     1.54554423e+00  0.00000000e+00]
#   ...
#   [ 4.46153846e+00  8.07183365e-01  6.98544699e-02 -1.12781955e-02
#     1.57842815e+00  1.80000000e+01]
#   [ 4.38461538e+00  7.92060491e-01  9.97920998e-03 -2.25563910e-02
#     1.57842815e+00  0.00000000e+00]
#   [ 4.38461538e+00  7.95841210e-01  1.09771310e-01 -3.00751880e-02
#     1.57842815e+00  0.00000000e+00]]
#
#  [[ 4.23076923e+00  8.56332703e-01  3.99168399e-02  4.88721805e-02
#     1.51266031e+00  1.07000000e+02]
#   [ 4.38461538e+00  8.60113422e-01 -1.66320166e-03  3.94736842e-02
#     1.54554423e+00  0.00000000e+00]
#   [ 4.23076923e+00  8.48771267e-01  3.82536383e-02  3.38345865e-02
#     1.54554423e+00  0.00000000e+00]
#   ...
#   [ 4.38461538e+00  7.92060491e-01  9.97920998e-03 -2.25563910e-02
#     1.57842815e+00  0.00000000e+00]
#   [ 4.38461538e+00  7.95841210e-01  1.09771310e-01 -3.00751880e-02
#     1.57842815e+00  0.00000000e+00]
#   [ 4.61538462e+00  7.76937618e-01  9.48024948e-02 -5.63909774e-03
#     1.57842815e+00  0.00000000e+00]]
#
#  [[ 4.38461538e+00  8.60113422e-01 -1.66320166e-03  3.94736842e-02
#     1.54554423e+00  0.00000000e+00]
#   [ 4.23076923e+00  8.48771267e-01  3.82536383e-02  3.38345865e-02
#     1.54554423e+00  0.00000000e+00]
#   [ 4.26923077e+00  8.41209830e-01  0.00000000e+00  3.75939850e-02
#     1.57842815e+00  0.00000000e+00]
#   ...
#   [ 4.38461538e+00  7.95841210e-01  1.09771310e-01 -3.00751880e-02
#     1.57842815e+00  0.00000000e+00]
#   [ 4.61538462e+00  7.76937618e-01  9.48024948e-02 -5.63909774e-03
#     1.57842815e+00  0.00000000e+00]
#   [ 4.65384615e+00  8.07183365e-01  3.99168399e-02  0.00000000e+00
#     1.57842815e+00  1.80000000e+01]]
#
#  ...
#
#  [[ 5.76923077e-01 -1.30434783e-01 -3.34303534e-01  6.20300752e-02
#     1.31535679e-01  0.00000000e+00]
#   [ 5.76923077e-01 -1.37996219e-01 -3.34303534e-01  6.20300752e-02
#     1.28904965e-01  0.00000000e+00]
#   [ 5.76923077e-01 -1.41776938e-01 -3.32640333e-01  6.20300752e-02
#     1.30220322e-01  0.00000000e+00]
#   ...
#   [ 5.38461538e-01 -1.49338374e-01 -1.58004158e-01  7.51879699e-02
#     1.31535679e-01  0.00000000e+00]
#   [ 5.00000000e-01 -1.60680529e-01 -8.31600832e-02  6.57894737e-02
#     1.31535679e-01  0.00000000e+00]
#   [ 5.00000000e-01 -1.60680529e-01 -4.98960499e-03  5.63909774e-02
#     1.31535679e-01  0.00000000e+00]]
#
#  [[ 5.76923077e-01 -1.37996219e-01 -3.34303534e-01  6.20300752e-02
#     1.28904965e-01  0.00000000e+00]
#   [ 5.76923077e-01 -1.41776938e-01 -3.32640333e-01  6.20300752e-02
#     1.30220322e-01  0.00000000e+00]
#   [ 5.38461538e-01 -1.49338374e-01 -2.96049896e-01  6.01503759e-02
#     1.31535679e-01  0.00000000e+00]
#   ...
#   [ 5.00000000e-01 -1.60680529e-01 -8.31600832e-02  6.57894737e-02
#     1.31535679e-01  0.00000000e+00]
#   [ 5.00000000e-01 -1.60680529e-01 -4.98960499e-03  5.63909774e-02
#     1.31535679e-01  0.00000000e+00]
#   [ 5.00000000e-01 -1.19092628e-01 -1.66320166e-03  7.14285714e-02
#     1.31535679e-01  6.80000000e+01]]
#
#  [[ 5.76923077e-01 -1.41776938e-01 -3.32640333e-01  6.20300752e-02
#     1.30220322e-01  0.00000000e+00]
#   [ 5.38461538e-01 -1.49338374e-01 -2.96049896e-01  6.01503759e-02
#     1.31535679e-01  0.00000000e+00]
#   [ 5.00000000e-01 -1.45557656e-01 -2.29521830e-01  6.39097744e-02
#     1.31535679e-01  0.00000000e+00]
#   ...
#   [ 5.00000000e-01 -1.60680529e-01 -4.98960499e-03  5.63909774e-02
#     1.31535679e-01  0.00000000e+00]
#   [ 5.00000000e-01 -1.19092628e-01 -1.66320166e-03  7.14285714e-02
#     1.31535679e-01  6.80000000e+01]
#   [ 6.15384615e-01 -4.72589792e-02 -1.66320166e-03  1.24060150e-01
#     1.31535679e-01  2.66000000e+02]]]
# [0.77693762 0.80718336 0.75047259 ... 0.5        0.61538462 0.61538462]

# %%
model = keras.Sequential()
model.add(
  keras.layers.Bidirectional(
    keras.layers.LSTM(
      units=128, 
      input_shape=(X_train.shape[1], X_train.shape[2])
    )
  )
)
model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.Dense(units=1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
history = model.fit(
    X_train, Y_train,
    epochs=30, 
    batch_size=32, 
    validation_split=0.1,
    shuffle=False
)
# Out:
# Epoch 1/30
# 112/112 [==============================] - 4s 18ms/step - loss: 0.8338 - val_loss: 0.7510
# Epoch 2/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.5306 - val_loss: 0.2602
# Epoch 3/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.2351 - val_loss: 0.0969
# Epoch 4/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.1316 - val_loss: 0.0818
# Epoch 5/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.1096 - val_loss: 0.0926
# Epoch 6/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.1016 - val_loss: 0.1122
# Epoch 7/30
# 112/112 [==============================] - 1s 11ms/step - loss: 0.0991 - val_loss: 0.1408
# Epoch 8/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.1104 - val_loss: 0.1167
# Epoch 9/30
# 112/112 [==============================] - 1s 11ms/step - loss: 0.0946 - val_loss: 0.0672
# Epoch 10/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.0742 - val_loss: 0.0658
# Epoch 11/30
# 112/112 [==============================] - 1s 11ms/step - loss: 0.0838 - val_loss: 0.1248
# Epoch 12/30
# 112/112 [==============================] - 1s 11ms/step - loss: 0.0784 - val_loss: 0.0924
# Epoch 13/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.0971 - val_loss: 0.0475
# Epoch 14/30
# 112/112 [==============================] - 1s 11ms/step - loss: 0.0911 - val_loss: 0.0693
# Epoch 15/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.0656 - val_loss: 0.0307
# Epoch 16/30
# 112/112 [==============================] - 1s 11ms/step - loss: 0.0812 - val_loss: 0.0640
# Epoch 17/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.0636 - val_loss: 0.0521
# Epoch 18/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.0593 - val_loss: 0.1844
# Epoch 19/30
# 112/112 [==============================] - 1s 11ms/step - loss: 0.0640 - val_loss: 0.0574
# Epoch 20/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.0545 - val_loss: 0.0600
# Epoch 21/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.0608 - val_loss: 0.0470
# Epoch 22/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.0516 - val_loss: 0.0555
# Epoch 23/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.0614 - val_loss: 0.0730
# Epoch 24/30
# 112/112 [==============================] - 1s 11ms/step - loss: 0.0696 - val_loss: 0.1148
# Epoch 25/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.0735 - val_loss: 0.0585
# Epoch 26/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.0628 - val_loss: 0.0744
# Epoch 27/30
# 112/112 [==============================] - 1s 11ms/step - loss: 0.0623 - val_loss: 0.3272
# Epoch 28/30
# 112/112 [==============================] - 1s 11ms/step - loss: 0.1016 - val_loss: 0.3497
# Epoch 29/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.0953 - val_loss: 0.1943
# Epoch 30/30
# 112/112 [==============================] - 1s 12ms/step - loss: 0.0799 - val_loss: 0.0715

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend();

# %%
Y_pred = model.predict(X_test)

# %%
Y_train_inv = sl_transformer.inverse_transform(sl_columns.reshape(1, -1))
Y_test_inv = sl_transformer.inverse_transform(sl_columns.reshape(1, -1))
Y_pred_inv = sl_transformer.inverse_transform(Y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-b7bb850d8932> in <module>
# ----> 1 Y_train_inv = sl_transformer.inverse_transform(Y_train.reshape(1, -1))
#       2 Y_test_inv = sl_transformer.inverse_transform(Y_test.reshape(1, -1))
#       3 Y_pred_inv = sl_transformer.inverse_transform(Y_pred)
#
# /opt/conda/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X)
#    1280         else:
#    1281             if self.with_scaling:
# -> 1282                 X *= self.scale_
#    1283             if self.with_centering:
#    1284                 X += self.center_
#
# ValueError: operands could not be broadcast together with shapes (1,11886) (3,) (1,11886)

# %%
plt.plot(np.arange(0, len(y_train)), y_train_inv.flatten(), 'g', label="history")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test_inv.flatten(), marker='.', label="true")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred_inv.flatten(), 'r', label="prediction")
plt.ylabel('CF419051')
plt.xlabel('Time Step')
plt.legend()
plt.show();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-41aa1fd235ae> in <module>
#       1 plt.plot(np.arange(0, len(y_train)), y_train_inv.flatten(), 'g', label="history")
#       2 plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test_inv.flatten(), marker='.', label="true")
# ----> 3 plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred_inv.flatten(), 'r', label="prediction")
#       4 plt.ylabel('CF419051')
#       5 plt.xlabel('Time Step')
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (3945,) and (1315,)

# %%
plt.plot(y_test_inv.flatten(), marker='.', label="true")
plt.plot(y_pred_inv.flatten(), 'r', label="prediction")
plt.ylabel('CF419051')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
print(y_pred_inv)
#y_pred_inv.to_csv('/home/jovyan/work/predictions/sw_pred.csv', index=False)
# Out:
# [[0.18741971]
#  [0.19367151]
#  [0.19410387]
#  ...
#  [0.22151604]
#  [0.22623481]
#  [0.22691785]]

# %%
print(y_pred_inv.dtype)


df_test.cols['sl_pred'] = 0.0
df_test.insert(loc=len(df_test.columns),column='sl_pred', value=

print(df_test)

df_y_pred = pd.DataFrame(y_pred_inv)
#df_y_pred.insert(loc=0, column='read_date', value='2020-01-01')
#df_test = test_inv.copy()

for i in range(len(df_test)):
  
    if (i == time_steps):
        j = 0
        df_test.iloc[i,6] == df_y_pred.iloc[j,0]
        print('i: ',i, 'date: ', df_test.index[i], df_test.iloc[i,6])
    
        j = j + 1

    
print(df_y_pred)

#
sda
df_y_pred = pd.DataFrame(y_pred_inv)  #,index=None,dtype=float
df_y_pred.insert(loc=0, column='read_date', value='2021-01-01')

#df['Date'] = pd.to_datetime(df['Date'])
df_y_pred.shape
#df_y_pred.insert(loc=0, column='read_date', value=player_vals)

df_y_pred

#df_test.to_csv('/home/jovyan/work/predictions/sw_pred_data.csv')
print(df_y_pred)

#df_test.reset_index(drop=False, inplace=True)

#df_test.join(df_y_pred)

print(df_test)
df_test.to_csv('/home/jovyan/work/predictions/sw_pred_data.csv')
# Out:
#   File "<ipython-input-358-d4d3625d6ccf>", line 9
#     df_y_pred = pd.DataFrame(y_pred_inv)
#     ^
# SyntaxError: invalid syntax
