# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from pandas.plotting import register_matplotlib_converters

# %%
df = pd.read_csv(
  "/home/jovyan/work/model/training_data/rf_training_data1.csv", 
  parse_dates=['read_date'], 
  index_col="read_date"
)

# %%
df.shape
# Out:
# (1750, 18)

# %%
df.head()
# Out:
#             sl_read1     bl_meter1  bl_ahd1  mean_temp1     bl_meter2  \
# read_date
# 2005-12-13     0.314  GW967137.1.1  253.264      19.825  GW967137.2.2
# 2005-12-16     0.310  GW967137.1.1  253.265      19.843  GW967137.2.2
# 2005-12-17     0.475  GW967137.1.1  253.296      19.800  GW967137.2.2
# 2005-12-29     0.315  GW967137.1.1  253.134      19.719  GW967137.2.2
# 2006-01-13     0.199  GW967137.1.1  253.027      19.600  GW967137.2.2
#
#             bl_ahd2  mean_temp2     bl_meter3  bl_ahd3  mean_temp3  \
# read_date
# 2005-12-13  251.618      21.400  GW967138.1.1  283.135      18.900
# 2005-12-16  251.641      21.400  GW967138.1.1  283.169      18.900
# 2005-12-17  251.680      21.400  GW967138.1.1  283.198      18.900
# 2005-12-29  251.611      21.387  GW967138.1.1  283.135      19.179
# 2006-01-13  251.589      21.387  GW967138.1.1  283.001      19.429
#
#                bl_meter4  bl_ahd4  mean_temp4  sl_meter  rf_meter  rf_read1  \
# read_date
# ...

# %% [markdown]
# ## https://medium.com/swlh/time-series-analysis-7006ea1c3326

# %% [markdown]
# plt.plot(history.history['loss'], label='train')
# plt.plot(history.history['val_loss'], label='test')
# plt.legend();

# %%
fig1 = df.plot( y=['bl_ahd1', 'bl_ahd2'],figsize=(15,8), grid=True, title='Elfin Ground Water Depth over Time', xlabel='Date',ylabel='AHD(m)').get_figure()
plt.show()

# %%
diff_level = df['bl_ahd1'] - df['bl_ahd2']
print(diff_level)
diff_level.plot(figsize=(20,20), linewidth=3, fontsize=20)
plt.xlabel('Year',fontsize=20);
plt.show()
# Out:
# read_date
# 2005-12-13    1.646
# 2005-12-16    1.624
# 2005-12-17    1.616
# 2005-12-29    1.523
# 2006-01-13    1.438
#               ...
# 2022-06-01    1.271
# 2022-06-03    1.276
# 2022-06-04    1.272
# 2022-06-08    1.276
# 2022-06-10    1.278
# Length: 1750, dtype: float64

# %%
df[['bl_ahd1']].plot(figsize=(20,10), linewidth=3, fontsize=20)
df[['bl_ahd2']].plot(figsize=(20,10), linewidth=3, fontsize=20)
plt.xlabel('Year',fontsize=20);

# %%
alluvium = df[['bl_ahd1']]
hardrock = df[['bl_ahd2']]

# %%
alluvium.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
hardrock.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year',fontsize=20);
